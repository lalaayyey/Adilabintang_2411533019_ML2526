# %% [markdown]
# <a href="https://colab.research.google.com/github/lalaayyey/Adilabintang_2411533019_ML2526/blob/main/praktikum2/sklearn_naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/lalaayyey/Adilabintang_2411533019_ML2526/main/praktikum2/Breast_cancer_data.csv"

data = pd.read_csv(url)

# %%
print(data.head())
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
X = data.iloc[:, :-1]   # semua kolom kecuali terakhir
y = data.iloc[:, -1]    # kolom terakhir (diagnosis)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=41
)

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

print("Akurasi =", accuracy_score(y_test, y_pred))
print("F1-Score =", f1_score(y_test, y_pred))
# Out:
# Akurasi = 0.9473684210526315
# F1-Score = 0.96

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
